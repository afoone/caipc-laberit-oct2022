# %%
import pandas as pd
import numpy as np
import math

# %%
columns = [
  'symboling',
  'normalized-losses',
  'make',
  'aspiration',
  'num-of-doors',
  'body-style',
  'drive-wheels',
  'engine-location',
 'wheel-base',
 'length',
 'width',
 'height',
 'curb-weight',
 'engine-type',
 'num-of-cylinders',
 'engine-size',
 'fuel-system',
 'bore',
 'stroke',
 'compression-ratio',
 'horsepower',
 'peak-rpm',
 'city-mpg',
 'highway-mpg',
 'price'
 ]

# %%
columns
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
coches = pd.read_csv('data/imports-85.data', names=columns)

# %%
coches.head()
# Out:
#   symboling normalized-losses make aspiration num-of-doors   body-style  \
# 3         ?       alfa-romero  gas        std          two  convertible
# 3         ?       alfa-romero  gas        std          two  convertible
# 1         ?       alfa-romero  gas        std          two    hatchback
# 2       164              audi  gas        std         four        sedan
# 2       164              audi  gas        std         four        sedan
#
#   drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# 3          rwd           front        88.6   168.8  ...          130
# 3          rwd           front        88.6   168.8  ...          130
# 1          rwd           front        94.5   171.2  ...          152
# 2          fwd           front        99.8   176.6  ...          109
# 2          4wd           front        99.4   176.6  ...          136
#
#    fuel-system  bore stroke compression-ratio  horsepower peak-rpm city-mpg  \
# ...

# %%
coches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 3 to -1
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    object
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   aspiration         205 non-null    object
#  4   num-of-doors       205 non-null    object
#  5   body-style         205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        205 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
# ...

# %%
coches['num-of-cylinders'].head()
# Out:
# 3    four
# 3    four
# 1     six
# 2    four
# 2    five
# Name: num-of-cylinders, dtype: object

# %%
coches = coches.replace('?', np.nan)

# %%
coches['horsepower'].isna().sum()
# Out:
# 2

# %%
coches['horsepower'] = coches['horsepower'].astype('float')

# %%
coches['num-of-cylinders'].value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: num-of-cylinders, dtype: int64

# %%
def text_to_number(x):
    if (x == 'four'):
        return 4
    elif (x == 'six'):
        return 6
    elif (x == 'five'):
        return 5
    elif (x == 'eight'):
        return 8
    elif (x == 'two'):
        return 2
    elif (x == 'three'):
        return 3
    elif (x == 'twelve'):
        return 12
    else:
        return 0
coches['num-of-cylinders'] = coches['num-of-cylinders'].apply(text_to_number).astype('float')

# %%
coches['num-of-cylinders']
coches['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
coches['num-of-doors'] = coches['num-of-doors'].apply (
    lambda x: 4 if x=='four' else 2
)

# %%
coches['price'].value_counts()
# Out:
# 8921     2
# 18150    2
# 8845     2
# 8495     2
# 7609     2
#         ..
# 45400    1
# 16503    1
# 5389     1
# 6189     1
# 22625    1
# Name: price, Length: 186, dtype: int64

# %%
coches['peak-rpm'].value_counts()
# Out:
# 5500    37
# 4800    36
# 5000    27
# 5200    23
# 5400    13
# 6000     9
# 5800     7
# 5250     7
# 4500     7
# 4150     5
# 4200     5
# 4350     4
# 4750     4
# 5100     3
# 5900     3
# 4250     3
# 4400     3
# 6600     2
# 4650     1
# 5600     1
# 5750     1
# 4900     1
# 5300     1
# Name: peak-rpm, dtype: int64

# %%
num_cols = [
'symboling         ', 
' num-of-doors     ',  
' wheel-base       ',  
' length           ',  
' width            ',  
' height           ',  
' curb-weight      ',  
' num-of-cylinders ',  
' engine-size      ',  
' compression-ratio',  
' horsepower       ',  
' peak-rpm         ',  
' city-mpg         ',  
' highway-mpg      ',  
' price            ']

# %%
numeric_columns = []

for col in num_cols: 
    numeric_columns.append(col.strip())

# %%
numeric_columns
# Out:
# ['symboling',
#  'num-of-doors',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'num-of-cylinders',
#  'engine-size',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
coches_n = coches[numeric_columns].copy()

# %%
coches_n = coches_n.astype('float')

# %%
coches_n
# Out:
#     symboling  num-of-doors  wheel-base  length  width  height  curb-weight  \
#  3        NaN           2.0        88.6   168.8   64.1    48.8       2548.0
#  3        NaN           2.0        88.6   168.8   64.1    48.8       2548.0
#  1        NaN           2.0        94.5   171.2   65.5    52.4       2823.0
#  2      164.0           4.0        99.8   176.6   66.2    54.3       2337.0
#  2      164.0           4.0        99.4   176.6   66.4    54.3       2824.0
# ..        ...           ...         ...     ...    ...     ...          ...
# -1       95.0           4.0       109.1   188.8   68.9    55.5       2952.0
# -1       95.0           4.0       109.1   188.8   68.8    55.5       3049.0
# -1       95.0           4.0       109.1   188.8   68.9    55.5       3012.0
# -1       95.0           4.0       109.1   188.8   68.9    55.5       3217.0
# -1       95.0           4.0       109.1   188.8   68.9    55.5       3062.0
#
# ...

# %%
coches_n.isnull().sum()
# Out:
# symboling            41
# num-of-doors          0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# num-of-cylinders      0
# engine-size           0
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
coches_n = coches_n.drop(columns = ['symboling'])

# %%
coches_n.isnull().sum()
# Out:
# num-of-doors         0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# num-of-cylinders     0
# engine-size          0
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
coches_n = coches_n.dropna()

# %%
coches_n.isnull().sum()
# Out:
# num-of-doors         0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# num-of-cylinders     0
# engine-size          0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
price = coches_n['price']
coches_n = (coches_n - coches_n.mean())/coches_n.std()
coches_n['price'] = price

# %%
coches_n
# Out:
#     num-of-doors  wheel-base    length     width    height  curb-weight  \
#  3     -1.131763   -1.678607 -0.432533 -0.844346 -2.033429    -0.015447
#  3     -1.131763   -1.678607 -0.432533 -0.844346 -2.033429    -0.015447
#  1     -1.131763   -0.709939 -0.238545 -0.181152 -0.562263     0.513546
#  2      0.879137    0.160221  0.197928  0.150445  0.214186    -0.421329
#  2      0.879137    0.094548  0.197928  0.245187  0.214186     0.515470
# ..           ...         ...       ...       ...       ...          ...
# -1      0.879137    1.687104  1.184033  1.429462  0.704574     0.761692
# -1      0.879137    1.687104  1.184033  1.382091  0.704574     0.948282
# -1      0.879137    1.687104  1.184033  1.429462  0.704574     0.877109
# -1      0.879137    1.687104  1.184033  1.429462  0.704574     1.271449
# -1      0.879137    1.687104  1.184033  1.429462  0.704574     0.973289
#
#     num-of-cylinders  engine-size  compression-ratio  horsepower  peak-rpm  \
# ...

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
def knn_train_test(train_cols, target_col, df):
    _df = df.copy()
    """
    Calcula la predicción y devuelve el rmse
    """
    k_split = math.trunc(len(_df)/5)
    print(k_split)
    for j in range(0,5):
        print(j, k_split*j,k_split*(j+1) )
        _df.loc[_df.index[(k_split*j):(k_split*(j+1) if j<4 else len(_df))], 'fold'] = j+1
    
    print (_df['fold'].value_counts())
    rmse_list = []

    for i in range(1,6):
        knn = KNeighborsRegressor()
        knn.fit(_df[_df['fold'] != i][train_cols],_df[_df['fold'] != i][target_col])
        pred = knn.predict(_df[_df['fold'] == i][train_cols])
        rmse = mean_squared_error(_df[_df['fold'] == i][target_col], pred)**0.5
        rmse_list.append(rmse)
        
    return rmse

# %%
knn_train_test(['num-of-doors', 'horsepower'], 'price', coches_n)
# Out:
# 39
# 0 0 39
# 1 39 78
# 2 78 117
# 3 117 156
# 4 156 195
# 5.0    199
# Name: fold, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [76], line 1
# ----> 1 knn_train_test(['num-of-doors', 'horsepower'], 'price', coches_n)
#
# Cell In [75], line 18, in knn_train_test(train_cols, target_col, df)
#      16 knn = KNeighborsRegressor()
#      17 knn.fit(_df[_df['fold'] != i][train_cols],_df[_df['fold'] != i][target_col])
# ---> 18 pred = knn.predict(_df[_df['fold'] == i][train_cols])
#      19 rmse = mean_squared_error(_df[_df['fold'] == i][target_col], pred)**0.5
#      20 rmse_list.append(rmse)
#
# File ~/miniforge3/envs/caipcoctubre/lib/python3.9/site-packages/sklearn/neighbors/_regression.py:229, in KNeighborsRegressor.predict(self, X)
#     213 """Predict the target for the provided data.
#     214
#     215 Parameters
#    (...)
# ...
